# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 3

# %% [markdown]
# ___
# ### *Bruno Kaczelnik, Guilherme Lotaif, Renato Tajima, Thiago Verardo*
# ___

# %% [markdown]
# # Análise de Airbnb nas maiores cidades americanas

# %% [markdown]
# ___
#
# ## 1. Introdução

# %% [markdown]
#    Neste Projeto será feita uma análise dos dados que possuimos de Airbnb nos Estados Unidos, e a partir dos dados que julgarmos pertinentes ao nosso estudo. Serão usados diferentes **métodos de predição** para descobrir`o preço de um aluguel dependendo das características fornecidas`, após usarmos os diferentes métodos, vamos comparar os resultados de cada método, finalmente poderemos concluir o projeto..
#
#    Um pouco mais sobre a plataforma digital Airbnb: Ela é utilizada para efetuar o aluguel de uma casa ou apartamento de outros usuários da própria plataforma. Com anúncios em 192 países, podemos concluir que é uma plataforma é bem grande, somente nos Estados Unidos existem aproximadamente 600.000 possiveis locais para aluguel. Com tantas opções, a escolha que o usuário faz quanto ao local é feita baseada nas **informações fornecidas pelo propretario**, tais informações podem variar desde quantos banheiros a residência possui, até se ela possui acesso a uma rede Wifi.

# %% [markdown]
# **Fonte do dataset:** www.kaggle.com/rudymizrahi/airbnb-listings-in-major-us-cities-deloitte-ml

# %% [markdown]
# ___
# ## 2. Minerando dados e características do dataset

# %% [markdown]
# O dataset que vamos utilizar nesse projeto possui diversas colunas com informações dos Airbnb nos Estados Unidos, portannto temos que percorrer todas essas colunas para fazer uma limpeza, e deixar somente as informações que serão pertinentes a nossa análise.

# %% [markdown]
# **Importando as bibliotecas que serão utilizadas:**

# %%
#Importando bibliotecas:
import os
import sys
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import pandas_profiling
import matplotlib.pyplot as plt
from scipy.stats import norm,probplot
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, r2_score

plt.style.use('ggplot')

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\PCDELL\Desktop\insper\CDD\projeto 3\Projeto-3-CDD---DPA-master\Projeto-3-CDD---DPA-master

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ### - Base de dados

# %%
#Importado o arquivo de treinamento:
df = pd.read_csv('train.csv')

# %%
#Análisando o tamanho do dataframe de treino:
linhas, colunas = df.shape
print("O Dataframe possui {0} linhas por {1} colunas.".format(linhas, colunas))
# Out:
# O Dataframe possui 74111 linhas por 29 colunas.

# %% [markdown]
# ...
#
# #### Limpando o dataframe de treino para ser análisado:
# Esta etapa consiste em uma preparação do dataframe para facilitar a análise no mesmo, assim evitando ocorrências de complicações ou erros que atrapalhem futuramento os nosssos classificadores. Portanto iremos limpar os titulos de cada coluna, vamos remover os valores nulos de cada categoria, assim como colunas desnecessárias.

# %%
#Removendo os espaços em branco dos nomes das colunas:
df.columns = [espaços.strip() for espaços in df.columns.tolist()]

# %%
#Transformando as datas do dataframe para o formato correto:
df["host_since"] = pd.to_datetime(df["host_since"], errors='coerce')
df["last_review"] = pd.to_datetime(df["last_review"], errors='coerce')
df["first_review"] = pd.to_datetime(df["first_review"], errors='coerce')

# %%
#Convertendo string de porcentagem para float:
df['host_response_rate'] = df['host_response_rate'].str.rstrip('%').astype('float')

# %%
#Removendo colunas que não sao pertinentes ao estudo:
df = df.drop(["latitude","longitude","name","thumbnail_url","id","description","amenities","zipcode"],axis=1);

# %%
#Apagando valores nulos que podem causar problemas posteriores:
df = df.dropna(axis=0, subset=['log_price', 'property_type', 'room_type', 'accommodates', 'bathrooms','bed_type',
                               'cancellation_policy', 'cleaning_fee', 'city','first_review', 'host_has_profile_pic', 
                               'host_identity_verified','host_response_rate', 'host_since', 'instant_bookable',
                               'last_review','neighbourhood', 'number_of_reviews', 'review_scores_rating',
                               'bedrooms', 'beds'])

# %%
#Corrigindo simplificação no arquivo:
df.loc[(df["instant_bookable"] == "f"),"instant_bookable"] = "False"
df.loc[(df["instant_bookable"] == "t"),"instant_bookable"] = "True"

df.loc[(df["host_has_profile_pic"] == "f"),"host_has_profile_pic"] = "False"
df.loc[(df["host_has_profile_pic"] == "t"),"host_has_profile_pic"] = "True"

df.loc[(df["host_identity_verified"] == "f"),"host_identity_verified"] = "False"
df.loc[(df["host_identity_verified"] == "t"),"host_identity_verified"] = "True"

# %%
df.head(2)
# Out:
#    log_price property_type        room_type  accommodates  bathrooms  \
# 1   5.129899     Apartment  Entire home/apt             7        1.0
# 2   4.976734     Apartment  Entire home/apt             5        1.0
#
#    bed_type cancellation_policy  cleaning_fee city first_review  ...   \
# 1  Real Bed              strict          True  NYC   2017-08-05  ...
# 2  Real Bed            moderate          True  NYC   2017-04-30  ...
#
#   host_identity_verified host_response_rate  host_since instant_bookable  \
# 1                  False              100.0  2017-06-19             True
# 2                   True              100.0  2016-10-25             True
#
#   last_review   neighbourhood number_of_reviews  review_scores_rating  \
# 1  2017-09-23  Hell's Kitchen                 6                  93.0
# 2  2017-09-14          Harlem                10                  92.0
#
#    bedrooms  beds
# 1       3.0   3.0
# 2       1.0   3.0
#
# [2 rows x 21 columns]

# %% [markdown]
# ...
#
#
# #### Transformando categorias qualiativas em quantiativas:
#
# O método usado para efetuar essa conversão é chamado de **One Hot Encoding**, que transforma variaveis categóricas em vetores binarios. Tal método transforma todas as variaveis em 0 menos a do item analisado, desse modo permitindo que sejam feitam análises em cima desse dados.
# <br>
# <br>

# %%
#Função para chamar o get_dummies e remover a coluna base:
def dummify(data, column_name):
    df1 = data.copy()
    df2 = pd.concat([df1.drop(column_name, axis=1), pd.get_dummies(data[column_name], prefix=column_name)], axis=1)
    return df2

#Transformando "category" em uma variável quantitativa:
DF = dummify(df, "property_type")
DF = dummify(DF, "room_type")
DF = dummify(DF, "bed_type")
DF = dummify(DF, "cancellation_policy")
DF = dummify(DF, "cleaning_fee")
DF = dummify(DF, "city")
DF = dummify(DF, "host_has_profile_pic")
DF = dummify(DF, "host_identity_verified")
DF = dummify(DF, "instant_bookable")
DF = dummify(DF, "neighbourhood") #Talvez tenha pouca influência

# %% [markdown]
# <br>
#
# ### - Análise descritiva

# %% [markdown]
# Após realizarmos o filtro, deve-se realizar uma análise exploratória dos dados, com o  objetivo de achar as váriaveis que mais influenciam no nosso objetivo e que assim possam nos ajudar a prever qual será a avaliação de um hotel aleatório. Ela será feita com o auxílio do pandas_profiling e seaborn.

# %% [markdown]
# #### Será que o tipo do quarto altera o seu valor?

# %%
Tipo = df.room_type.value_counts()

# %%
#Criando uma tabela com os dados:
plot = Tipo.plot(kind='bar',figsize=(5, 4), color = ["firebrick","tomato","salmon"])
ax = plt.subplot(111)
plt.title("\nTipos mais frequentes de Airbnb")
plt.ylabel('Quantidade')
plt.show()


prop = df.property_type.value_counts()
#Criando uma tabela com os dados:
plot = prop.head(5).plot(kind='bar',figsize=(5, 4), color = ["firebrick","tomato","salmon"])
ax = plt.subplot(111)
plt.title("\nTipos mais frequentes de Airbnb")
plt.ylabel('Quantidade')
plt.show()

# %%
entire,private,shared = [],[],[]
for tipo,preco in zip(df['room_type'],df['log_price']):
    if tipo == "Entire home/apt":
        entire.append(preco)
    elif tipo == "Private room":
        private.append(preco)
    elif tipo == "Shared room":
        shared.append(preco)

# %%
print(" Entire room:  {:.2f}\n".format(np.mean(entire)),
      "Private room: {:.2f}\n".format(np.mean(private)),
      "Shared room:  {:.2f}\n".format(np.mean(shared)))
# Out:
#  Entire room:  5.14
#  Private room: 4.30
#  Shared room:  3.78

# %%
df.plot(x='review_scores_rating', y='log_price', style='o')  
plt.title('Scores vs price')  
plt.xlabel('desde')  
plt.ylabel('preço')  
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.tight_layout()
sns.distplot(df['log_price'],bins = 35);
plt.show()

# %%
sns.distplot(df['review_scores_rating'], bins = 40);
plt.show()

# %%
sns.distplot(df['review_scores_rating'], bins = 40);

# %%
dfinho = df[["review_scores_rating","log_price"]]
dfinho.corr()
# Out:
#                       review_scores_rating  log_price
# review_scores_rating              1.000000   0.075249
# log_price                         0.075249   1.000000

# %%
#utilizandoo o pandas_profiling
#df é o dataframe após o filtro
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>22 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>43091 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>6.9 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>169.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_bedrooms"><code>bedrooms</code></a> has 4078 / 9.5% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_neighbourhood"><code>neighbourhood</code></a> has a high cardinality: 590 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_accommodates">accommodates<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>16</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (n)</th>
#                     <td>0</td>
#                 </tr>
#                 <tr cla

# %% [markdown]
# ___
# ## 3. Modelos de predição

# %% [markdown]
# Adequando nosso dataframe para as predições:

# %%
#Tirando colunas que não vamos precisar:
df_pred = DF.drop(["log_price","host_since","first_review","last_review"],axis=1)
DF = DF.drop(["host_since","first_review","last_review"],axis=1)

# %%
#Importando bibliotecas para usar no statsmodel:
from sklearn.linear_model import LinearRegression
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    import statsmodels.api as sm

#Estabelecendo variave random_seed:
RANDOM_SEED = 10
np.random.seed(RANDOM_SEED)

# %%
DF.shape
# Out:
# (43091, 656)

# %%
#Dividindo os dados do dataframe em teste e treino:
X_train, X_test, y_train, y_test = train_test_split(df_pred, DF.log_price, test_size = 0.33,random_state = RANDOM_SEED)

# %%
X_train.shape
# Out:
# (28870, 655)

# %%
X_test.shape
# Out:
# (14221, 655)

# %%
y_train.shape
# Out:
# (28870,)

# %%
y_test.shape
# Out:
# (14221,)

# %%
X_train_sm, X_test_sm, y_train_sm, y_test_sm = X_train, X_test, y_train, y_test

#Chamando o classificador com o statsmodel:
linear = LinearRegression()
Xc = sm.add_constant(X_train_sm)
model = sm.OLS(y_train_sm,Xc)
results = model.fit()

#Criando uma lista dos P Values:
Valores_p = list(results.pvalues)
#Criando uma lista do mesmo tamanho das colunas:
n = np.arange(0,len(Valores_p))
#Criando uma lista para atribui as colunas para excluir:
colunas_del = []
#Vamos fazer um loop para Selecionar as colunas para serem excluir:
for coluna,i in zip(DF.columns,Valores_p):
    #Considerando só os PVALUEs maiores que 0.6:
    if i > 0.1:
        #Adicionando as colunas na lista:
        colunas_del.append(coluna)

#Finalmente vamos deletar as colunas desnecessárias para os preditores:
DF = DF.drop(colunas_del,axis=1)


linear = LinearRegression()
Xc_ = sm.add_constant(X_train_sm)
model = sm.OLS(y_train_sm,Xc_)
results = model.fit()

print(r2_score(y_test, results.predict(X_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-e2cb38e8a00c> in <module>
#      29 results = model.fit()
#      30
# ---> 31 print(r2_score(y_test, results.predict(X_test)))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py in predict(self, exog, transform, *args, **kwargs)
#     852
#     853         predict_results = self.model.predict(self.params, exog, *args,
# --> 854                                              **kwargs)
#     855
#     856         if exog_index is not None and not hasattr(predict_results,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in predict(self, params, exog)
#     343             exog = self.exog
#     344
# --> 345         return np.dot(exog, params)
#     346
#     347     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# ValueError: shapes (14221,655) and (656,) not aligned: 655 (dim 1) != 656 (dim 0)

# %%
DF.shape

# %%
df_pred=DF.drop(["log_price"],axis=1)

# %% [markdown]
# ...<br>
# <br>
#
# o `MODELO DE PREDIÇÃO PELA MÉDIA (Sem uso de variável explicativa)`

# %%
X = np.mean(DF.log_price)
print('media=',X)
# Out:
# media= 4.772880520973572

# %% [markdown]
# ...<br>
# <br>
#
# o `MODELO DOS K VIZINHOS MAIS PRÓXIMOS (K-Nearest Neighbors Regression)`

# %%
#Importando as bibliotecas necessárias para esse modelo:
from sklearn.neighbors import KNeighborsRegressor

# %%
X_train_sk, X_test_sk, y_train_sk, y_test_sk = X_train, X_test, y_train, y_test

# Chamando o classificador:
knn = KNeighborsRegressor(n_neighbors=3)

#Fazendo um fit nos dados de treino(treinando o algoritmo):
knn.fit(X_train_sk, y_train_sk)

knn_pred = knn.predict(X_test_sk)

#Descobrindo a acurácia do modelo de predição:
knn_test = r2_score(y_test_sk, knn_pred)
print('R2 é de: {:.2f}'.format(knn_test))

# %% [markdown]
# ...<br>
# <br>
#
# o `MODELO DE REGRESSÃO LINEAR (Multiple Linear Regression)`

# %%
from sklearn.linear_model import LinearRegression

# %%
#Chamando o classificador:
linear = LinearRegression()

#Fazendo um fit nos dados de treino:
linear.fit(X_train, y_train)

linear_pred = linear.predict(X_test)

#Descobrindo a acurácia do modelo de predição:
linear_test = r2_score(y_test, linear_pred)
print('R2 é de: {:.2f}'.format(linear_test))

# %% [markdown]
# Estamos trabalhando para solucionar o problema deste modelo!

# %% [markdown]
# ...<br>
# <br>
#
# o `MODELO DE ÁRVORES DE REGRESSÃO (Decision Tree Regression)`

# %%
#Importando as bibliotecas necessárias para esse modelo:
from sklearn.tree import DecisionTreeRegressor

# %%
#Chamando o classificador:
tree = DecisionTreeRegressor()

#Fazendo um fit nos dados de treino:
tree.fit(X_train, y_train)   

tree_pred = tree.predict(X_test)

#Descobrindo a acurácia do modelo de predição:
tree_test = r2_score(y_test, tree_pred)
print("R2 é de: {:.2f}".format(tree_test))

# %% [markdown]
# ...<br>
# <br>
#
# o `MODELO RANDOM FOREST (Para comparação`

# %%
#Importando as bibliotecas necessárias para esse modelo:
from sklearn.ensemble import RandomForestRegressor

# %%
#Chamando o RandomForestClassifier:
model = RandomForestRegressor()

#Fazendo um fit nos dados de treino:
model.fit(X_train, y_train)

random_pred = model.predict(X_test)

#Descobrindo a acurácia do modelo de predição:
random_test = r2_score(y_test, random_pred)
print('R2 é de: {:.2f}'.format(random_test))
# Out:
# R2 é de: 0.69

# %% [markdown]
# ___
# ## 4. Processo e estatísticas de validação

# %% [markdown]
# A partir dos  nosso r2 obtidos através dos modelos criados anteriormente, podemos comparar os resultados que cada modelo de predição teve.

# %%
knn_train_pred = knn.predict(X_train)
knn_train = r2_score(y_train, knn_train_pred)

linear_train_pred = linear.predict(X_train)
linear_train = r2_score(y_train, linear_train_pred)

tree_train_pred = tree.predict(X_train)
tree_train = r2_score(y_train, tree_train_pred)

random_train_pred = model.predict(X_train)
random_train = r2_score(y_train, random_train_pred)

Valores_teste = [knn_test,linear_test,tree_test,random_test]
Valores_treino= [knn_train,linear_train,tree_train,random_train]

# %%
TABELA_P = {'r2_treino':Valores_treino,"r2_teste":Valores_teste}
TABELA_P['r2_treino'] = Valores_treino
TABELA_P['r2_teste'] = Valores_teste

# %%
TABELA_P
# Out:
# {'r2_treino': [0.7205391160102885,
#   0.7446425346279177,
#   0.9992935253575291,
#   0.9450766401070319],
#  'r2_teste': [0.4361268252526611,
#   -746845918954925.1,
#   0.500147407775555,
#   0.6937542742778955]}

# %% [markdown]
# ___
# ## 5. Conclusão

# %% [markdown]
# ___
# ## 6. Referências bibliográficas

# %% [markdown]
# https://www.mldata.io/tutorials/scikit_knn/

# %% [markdown]
# https://www.kaggle.com/pratsiuk/valueerror-unknown-label-type-continuous
